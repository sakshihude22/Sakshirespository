# %%
num = 100
print(num)
# Out:
# 100

# %%
num = 200
print(num)
# Out:
# 200

# %%
num = 300
num
# Out:
# 300

# %%
num =400
print(num)
# Out:
# 400

# %%
num = 500

# %%
n1 = 10
n2 = 20
n1
n2
# Out:
# 20

# %%
n1 = 10
n2 = 20
print(n1)
print(n2)
# Out:
# 10
# 20

# %%
n1 = 100
n2 = 200
n1,n2
# Out:
# (100, 200)

# %%
n1 = 10

# %%
n1, n2 =20
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 n1, n2 =20
#
# TypeError: cannot unpack non-iterable int object

# %%
n1, n2 = 10,20

# %%
n1 = 10,20

# %%
NUMBER = 100
NUMBER
# Out:
# 100

# %%
number = 200
number
# Out:
# 200

# %%
NUMber = 300
NUMber
# Out:
# 300

# %%
number123 = 400

# %%
123number = 500
123number
# Out:
#   Cell In[22], line 1
#     123number = 500
#       ^
# SyntaxError: invalid decimal literal

# %%
number^one=600
number^one
# Out:
#   Cell In[23], line 1
#     number^one=600
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
number*one = 700
number*one
# Out:
#   Cell In[24], line 1
#     number*one = 700
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
number one= 700
number one
# Out:
#   Cell In[25], line 1
#     number one= 700
#            ^
# SyntaxError: invalid syntax

# %%
number$one= 300
number$one
# Out:
#   Cell In[26], line 1
#     number$one= 300
#           ^
# SyntaxError: invalid syntax

# %%
areaofcircle=100
areaofcircle
# Out:
# 100

# %%
number = 100
number
# Out:
# 100

# %%
NUMBER = 200
NUMBER
# Out:
# 200

# %%
NUMber = 300
NUMber
# Out:
# 300

# %%
123number = 400
123number
# Out:
#   Cell In[4], line 1
#     123number = 400
#       ^
# SyntaxError: invalid decimal literal

# %%
number123= 500
number123
# Out:
# 500

# %%
number123= 500
number123
# Out:
# 500

# %%
number$one= 700
number$one
# Out:
#   Cell In[7], line 1
#     number$one= 700
#           ^
# SyntaxError: invalid syntax

# %%
number_one = 1000
number_one
# Out:
# 1000

# %%
number

# %%
_ = 900
_
# Out:
# 900

# %%
name = Naresh IT
name
# Out:
#   Cell In[11], line 1
#     name = Naresh IT
#                   ^
# SyntaxError: invalid syntax

# %%
NareshIT = 200
name = NareshIT
name
# Out:
# 200

# %%
name ='NareshIT'
name
# Out:
# 'NareshIT'

# %%
if = 700
if
# Out:
#   Cell In[16], line 1
#     if = 700
#        ^
# SyntaxError: invalid syntax

# %%
100=500
100
# Out:
#   Cell In[17], line 1
#     100=500
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
100==500
# Out:
# False

# %%
false          #variable
FALSE
False             #keyword
"false"             #string

# %%
sum = 600

# %%
max = 700
max
# Out:
# 700

# %%
l= [40,50,60]
min(l)
# Out:
# 40

# %%
l=[40,50,60]
max(l)
# Out:
# 60

# %%
m=[40,50,60]
max(m)
# Out:
# 60

# %% [markdown]
# - if we miss the bracates for inbuilt functions
# - it will does not throw error
# - it will indicate in two ways
#     - it will display as functions
#     - it will display as bound method
# - this concept we will discuss in functions

# %%
import os 
os.getcwd
# Out:
# <function nt.getcwd()>

# %%
import time
time.sleep(6)

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Hude Sakshi Mahadev\\Documents\\Naresh IT'

# %%
if =700
if
# Out:
#   Cell In[4], line 1
#     if =700
#        ^
# SyntaxError: invalid syntax

# %%
else = 600
else
# Out:
#   Cell In[5], line 1
#     else = 600
#     ^
# SyntaxError: invalid syntax

# %%
100 = 100
100
# Out:
#   Cell In[6], line 1
#     100 = 100
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
100 == 100
# Out:
# True

# %%
sum=1000
sum
# Out:
# 1000

# %%
min = 300
min
# Out:
# 300

# %%
_=900
_
# Out:
# 900

# %% [markdown]
# - veriables are **case sensitive**
#     - which means both capital and small letters are different variables
# - variables are allowed number as **suffix**
#     - Ex: number123=300
# - variables are not allowed number as **prefix**
#     - Ex:123number=400
# - variables does not allow special characters
#     - Ex:number$one = 700
# -Only underscore can be allowed : number_one = 100
# - keywords are not allowed use variables
#     - 30-35 keywords are there like if , else , for, while etc,
# In built functions can be alloewd, but
